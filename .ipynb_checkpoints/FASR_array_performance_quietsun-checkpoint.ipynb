# %% [markdown]
# # Imaging Performance Comparison (Quiet Sun)
# This notebook loops over different noise levels and calibration errors to generate, corrupt, image, and compare solar flare datasets.

# %%
import fasr_solar_simul as fss
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import j1
from scipy.constants import c
import os
from casatasks import tclean, applycal, clearcal
from datetime import datetime
from pathlib import Path
from tqdm import tqdm
import timeit

# Speed of light in m/s
C_LIGHT = c
import matplotlib
# %matplotlib inline

# %%
from importlib import reload

reload(fss)
target = 'Quiet_Sun'
figsubfolder = 'figs/'
model_dir = '../fasr_sim/skymodels/quiet_sun/'

# %% [markdown]
# # Imaging Performance Comparison
# looping over different noise levels and calibration errors to generate, corrupt, image, and compare

# %% [markdown]
# ## Set up the simulation

# %%
# List of all available frequencies in GHz
freq_list = ['1GHz', '2GHz', '5GHz', '10GHz', '20GHz']
imsizes = [512, 512, 1024, 2048, 4096]
cells = ['4.8arcsec', '4.8arcsec', '2.4arcsec', '1.2arcsec', '0.6arcsec']
scales = [[0, 5, 10, 50], [0, 4, 10, 40], [0, 6, 20, 80], [0, 5, 10, 40, 160], [0, 10, 40, 80, 320]]
#freq_list = ['1GHz']
#imsizes = [512]
#cells = ['4.8arcsec']
#scales = [[0, 5, 10, 50]]

# List of configurations
project = 'FASR-A'
#config_files = ['fasr_Log_Spiral-168.cfg', 'fasr-a_random_spiral_hybrid_120.cfg']
config_files = ['fasr-a_random_spiral_hybrid_120.cfg']

## Antenna temperature noise levels
tsys_all = [300.]

## Define the fractional gain errors tuples: (phase and amplitude)
# 6 degrees (or 1.7% of phase error is equivalent to 10% of amplitude error )
#cal_errors = [(0., 0.), (0.017, 0.1)]
cal_errors = [(0., 0.)]

# Define channel width and integration time
channel_width_mhz = 24. # channel width in MHz
integration_time = 1. # Time per integration in seconds
duration = 1. # Total imaging duration in seconds

# Reference timestamp for the observation series
reftime_obj = datetime(2020, 11, 26, 20, 0, 0)

# Flags to control overwriting existing data products
overwrite_ms   = False  # Overwrite measurement set?
overwrite_im   = False  # Overwrite image products?
overwrite_plot = True  # Overwrite existing plots?

weighting = 'uniform'
# Deconvolution algorithm choice
#deconvolver = 'hogbom'
#niter = 0

deconvolver = 'multiscale'
niter = 10000

# %%
reload(fss)
fss.plt_radial_profiles(dr=20, radius_cutoffs=[1.4, 1.35, 1.3, 1.25, 1.2, 1.19, 1.17, 1.15])
# Out:
# Solar radius at 2020-11-26T20:45:47: 972.12 arcsec
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0001 Jy/pixel at 1.00 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0004 Jy/pixel at 2.00 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0017 Jy/pixel at 3.99 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0001 Jy/pixel at 1.00 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0066 Jy/pixel at 7.96 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0104 Jy/pixel at 10.02 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0225 Jy/pixel at 14.71 GHz
# Pixel scale: 1.20 x 1.20 arcsec
# Minimum flux threshold: 0.0416 Jy/pixel at 20.00 GHz

# %%
    hdul = fits.open(solar_model)
    flux = hdul[0].data[0, 0]
    header = hdul[0].header

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 header['date_obs']
#
# File ~/anaconda3/envs/suncasa38/lib/python3.8/site-packages/astropy/io/fits/header.py:156, in Header.__getitem__(self, key)
#     153 else:
#     154     keyword = key
# --> 156 card = self._cards[self._cardindex(key)]
#     158 if card.field_specifier is not None and keyword == card.rawkeyword:
#     159     # This is RVKC; if only the top-level keyword was specified return
#     160     # the raw value, not the parsed out float value
#     161     return card.rawvalue
#
# File ~/anaconda3/envs/suncasa38/lib/python3.8/site-packages/astropy/io/fits/header.py:1753, in Header._cardindex(self, key)
#    1750         indices = self._rvkc_indices.get(keyword, None)
#    1752 if not indices:
# -> 1753     raise KeyError(f"Keyword {keyword!r} not found.")
#    1755 try:
#    1756     return indices[n]
#
# KeyError: "Keyword 'DATE_OBS' not found."

# %% [markdown]
# ## Simulate visibility and do imaging

# %%
# %matplotlib inline
reload(fss)

import time

reftime = reftime_obj.strftime('%Y/%m/%d/%H:%M:%S')

figdir = os.path.join(project, figsubfolder)
if not os.path.exists(figdir):
    os.makedirs(figdir)
    
caltbdir = os.path.join(project, 'caltbs')
if not os.path.exists(caltbdir):
    os.makedirs(caltbdir)

for config_file in config_files:
    cfg_suffix = os.path.basename(config_file.rstrip(".cfg"))
    for freqstr, imsize, cell, scale in zip(freq_list, imsizes, cells, scales):
        solar_model = f'{model_dir}/solar_disk_model_20201126.{freqstr}.fits'
        for tsys in tsys_all:
            # Calculate theoretical sensitivity with natural weighting
            antenna_params = np.genfromtxt(config_file, comments='#')
            dish_diameter = antenna_params[0, 3]
            uv_cell = 1. / (imsize * float(cell.rstrip('arcsec')) / 206265.)
            total_flux = fss.calc_total_flux_on_dish(solar_model, dish_diameter=dish_diameter, freqghz=freqstr)
            tant = fss.total_flux_to_tant(total_flux, eta_a=0.6, dish_diameter=dish_diameter)
            print(f'Tant: {tant:.0f}K')
            noisejy, sigma_na, sigma_un = fss.calc_noise(tsys, config_file, dish_diameter=dish_diameter, 
                                                         total_flux=total_flux, duration=duration,
                                                         integration_time=integration_time, 
                                                         channel_width_mhz=channel_width_mhz, 
                                                         freqghz=freqstr, uv_cell=uv_cell)
            sigma_jy = sigma_un / np.sqrt((duration / integration_time))
                
            for phaerr, amperr in cal_errors:
                phaerr_deg = np.rad2deg(phaerr * 2 * np.pi)
                gaintable = [f'caltb_FASR_corrupt_{phaerr_deg:.0f}deg.ph',
                             f'caltb_FASR_corrupt_{np.int_(amperr * 100)}pct.amp']
                msname = fss.make_msname(project, target, freqstr, reftime_obj, duration, integration_time, config_file, tsys)
                imname = fss.make_imname(msname, deconvolver, phaerr, amperr)
                if niter == 0:
                    imname = imname.replace(deconvolver, 'dirty')
                msfile = f'{msname}.ms'
                if os.path.exists(msfile):
                    if overwrite_ms:
                        os.system('rm -rf ' + msfile)
                    else:
                        pass
                
                if not os.path.exists(msfile):
                    print('Start generating ms')
                    msfile, = fss.generate_ms(config_file, solar_model, reftime, freqstr, integration_time=integration_time,
                                    duration=duration, channel_width_mhz=channel_width_mhz, 
                                    msname=msfile, tsys=tsys, usehourangle=True)

                if os.path.exists(f'{imname}.image'):
                    if overwrite_im:
                        junk = ['.image', '.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                        for j in junk:
                            os.system(f'rm -rf {imname}{j}')

                if not os.path.exists(f'{imname}.image'):
                    tstart = time.time()
                    print('Start deconvolution')
                    if not os.path.exists(gaintable[0]):
                        gaintable = fss.generate_caltb(msfile, caltype=['ph', 'amp'], 
                                                       calerr=[phaerr, amperr], caltbdir=caltbdir)
                    clearcal(vis=msfile)
                    applycal(vis=msfile, gaintable=gaintable, applymode='calonly', calwt=False)
                    if deconvolver == 'hogbom':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)
                    elif deconvolver == 'multiscale':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, scales=scale, 
                               gain=0.2, cycleniter=200, minpsffraction=0.1, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)                        
                    junk = ['.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                    for j in junk:
                        os.system(f'rm -rf {imname}{j}')
                    tend = time.time()
                    print(f'deconvolution completed in {(tend - tstart)/60.:.2f} minutes')
                    

                figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.jpg')
                #figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.ar.jpg')
                if os.path.exists(figname):
                    if overwrite_plot:
                        os.system(f'rm -rf {figname}')

                if not os.path.exists(figname):
                    reload(fss)
                    ## cleaned image
                    image1 = imname + '.image'
                    ## model image
                    image2 = os.path.join(project+'/msfiles/Quiet_Sun/', os.path.basename(solar_model.replace('.fits', '.im')))
                    ## meta information of the images
                    image_meta = {'title': [f'Image ({deconvolver})', 'Model (convolved)'],
                                  'freq': freqstr.lstrip("0"),
                                  'array_config': config_file,
                                  'tsys': f'{tsys:.0f}K',
                                  'tant': f'{tant:.0f}K',
                                  'sigma_jy': f'{sigma_jy:.1f}Jy/beam',
                                  'cal_error': f'{phaerr_deg:.0f}'+r'$^{\circ}$ Pha' + f' & {np.int_(amperr * 100)}% Amp',
                                  'duration': f'{duration}s',
                                  'weighting': weighting,
                                  }
                    print('Start plotting')
                    fig, axs = fss.plot_two_casa_images_with_convolution(image1, image2,
                                                                         crop_fraction=(0.0, 1.0),
                                                                         #crop_fraction=((0.17, 0.37), (0.25, 0.45)),
                                                                         rms_mask_radius=1.2,
                                                                         figsize=(15, 4),
                                                                         image_meta=image_meta,
                                                                         cmap='hinodexrt',
                                                                         vmax=50,
                                                                         compare_two=False,
                                                                         contour_levels=[0.025, 0.05, 0.1, 0.2, 0.4,
                                                                                         0.8],
                                                                         conv_tag=f'.{cfg_suffix}',
                                                                         overwrite_conv=False)

                    fig.savefig(figname, dpi=300)
# Out:
# Total flux within primary beam used to calcuate the antenna temperature: 21.6 sfu
# Tant: 83K
# UV Grid: 267 x 267 cells covering +/- 11242.7 wavelengths
# 21.5883453125
# Calculate antenna temperature from total flux 21.5883453125 sfu incident on the dish
# Total noise temperature (K): 3.829e+02 K
# Estimated natural weighting point source sensitivity per integration per channel sigma_na: 1.294e+00 Jy/beam
# Estimated uniform weighting point source sensitivity per integration per channel sigma_un: 2.076e+00 Jy/beam
# Estimated noise per baseline per channel per polarization per integration: 1.547e+02 Jy for 7140 baselines
# Start plotting
# Peak of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_1GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image: 1.337e+06 K
# rms of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_1GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 6.550e+03 K
# SNR of the image: 204.1
# Peak of solar_disk_model_20201126.1GHz.im: 1.279e+06 K
# rms of solar_disk_model_20201126.1GHz.im (excluding solar disk): 5.890e+03 K
# Plotting image with vmin=-6.550e+04 K, vmax=6.684e+05 K
# Plotting convolved image with vmin=-6.550e+04 K, vmax=6.684e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2565: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2600: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-02-02 15:42:32; runtime: 0.67 seconds
# Total flux within primary beam used to calcuate the antenna temperature: 29.2 sfu
# Tant: 112K
# UV Grid: 535 x 535 cells covering +/- 22485.4 wavelengths
# 29.196803125
# Calculate antenna temperature from total flux 29.196803125 sfu incident on the dish
# Total noise temperature (K): 4.121e+02 K
# Estimated natural weighting point source sensitivity per integration per channel sigma_na: 1.393e+00 Jy/beam
# Estimated uniform weighting point source sensitivity per integration per channel sigma_un: 1.843e+00 Jy/beam
# Estimated noise per baseline per channel per polarization per integration: 1.665e+02 Jy for 7140 baselines
# Start plotting
# Peak of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_2GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image: 5.577e+05 K
# rms of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_2GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 2.757e+03 K
# SNR of the image: 202.3
# Peak of solar_disk_model_20201126.2GHz.im: 5.488e+05 K
# rms of solar_disk_model_20201126.2GHz.im (excluding solar disk): 1.930e+03 K
# Plotting image with vmin=-2.757e+04 K, vmax=2.788e+05 K
# Plotting convolved image with vmin=-2.757e+04 K, vmax=2.788e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2565: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2600: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-02-02 15:42:33; runtime: 0.58 seconds
# Total flux within primary beam used to calcuate the antenna temperature: 76.8 sfu
# Tant: 295K
# UV Grid: 1339 x 1339 cells covering +/- 56213.5 wavelengths
# 76.7877375
# Calculate antenna temperature from total flux 76.7877375 sfu incident on the dish
# Total noise temperature (K): 5.949e+02 K
# Estimated natural weighting point source sensitivity per integration per channel sigma_na: 2.011e+00 Jy/beam
# Estimated uniform weighting point source sensitivity per integration per channel sigma_un: 2.250e+00 Jy/beam
# Estimated noise per baseline per channel per polarization per integration: 2.403e+02 Jy for 7140 baselines
# Start plotting
# Peak of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_5GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image: 2.906e+05 K
# rms of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_5GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 2.692e+03 K
# SNR of the image: 107.9
# Peak of solar_disk_model_20201126.5GHz.im: 3.228e+05 K
# rms of solar_disk_model_20201126.5GHz.im (excluding solar disk): 1.555e+03 K
# Plotting image with vmin=-2.692e+04 K, vmax=1.453e+05 K
# Plotting convolved image with vmin=-2.692e+04 K, vmax=1.453e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2565: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2600: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-02-02 15:42:34; runtime: 0.55 seconds
# Total flux within primary beam used to calcuate the antenna temperature: 247.0 sfu
# Tant: 949K
# UV Grid: 2679 x 2679 cells covering +/- 112427.0 wavelengths
# 247.0279
# Calculate antenna temperature from total flux 247.0279 sfu incident on the dish
# Total noise temperature (K): 1.249e+03 K
# Estimated natural weighting point source sensitivity per integration per channel sigma_na: 4.221e+00 Jy/beam
# Estimated uniform weighting point source sensitivity per integration per channel sigma_un: 4.423e+00 Jy/beam
# Estimated noise per baseline per channel per polarization per integration: 5.044e+02 Jy for 7140 baselines
# Start plotting
# Peak of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_10GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image: 3.723e+05 K
# rms of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_10GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 3.508e+03 K
# SNR of the image: 106.1
# Peak of solar_disk_model_20201126.10GHz.im: 3.776e+05 K
# rms of solar_disk_model_20201126.10GHz.im (excluding solar disk): 1.638e+03 K
# Plotting image with vmin=-3.508e+04 K, vmax=1.862e+05 K
# Plotting convolved image with vmin=-3.508e+04 K, vmax=1.862e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2565: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2600: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-02-02 15:42:35; runtime: 0.62 seconds
# Total flux within primary beam used to calcuate the antenna temperature: 927.8 sfu
# Tant: 3562K
# UV Grid: 5358 x 5358 cells covering +/- 224854.0 wavelengths
# 927.7726
# Calculate antenna temperature from total flux 927.7726 sfu incident on the dish
# Total noise temperature (K): 3.862e+03 K
# Estimated natural weighting point source sensitivity per integration per channel sigma_na: 1.306e+01 Jy/beam
# Estimated uniform weighting point source sensitivity per integration per channel sigma_un: 1.324e+01 Jy/beam
# Estimated noise per baseline per channel per polarization per integration: 1.560e+03 Jy for 7140 baselines
# Start plotting
# Peak of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_20GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image: 5.214e+05 K
# rms of fasr_fasr-a_random_spiral_hybrid_120_Quiet_Sun_20GHz_20201126T20UT_dur1s_int1s_noise300K_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 4.531e+03 K
# SNR of the image: 115.1
# Peak of solar_disk_model_20201126.20GHz.im: 5.610e+05 K
# rms of solar_disk_model_20201126.20GHz.im (excluding solar disk): 1.700e+03 K
# Plotting image with vmin=-4.531e+04 K, vmax=2.607e+05 K
# Plotting convolved image with vmin=-4.531e+04 K, vmax=2.607e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2565: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2600: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-02-02 15:42:37; runtime: 1.07 seconds

# %% [markdown]
# ## The following simulation is for FASR-B

# %%
# List of all available frequencies in GHz
freq_list = ['1GHz', '2GHz']
imsizes = [512, 512]
cells = ['4.8arcsec', '4.8arcsec']
scales = [[0, 5, 10, 50], [0, 4, 10, 40]]

# List of configurations
project = 'FASR-B'
config_files = ['fasr-b_spiral_72.cfg']

## Antenna temperature noise levels
noise_levels = ['0.005MK', '0.01MK'][:1]

## Define the fractional gain errors tuples: (phase and amplitude)
# 6 degrees (or 1.7% of phase error is equivalent to 10% of amplitude error )
#cal_errors = [(0., 0.), (0.017, 0.1)]
cal_errors = [(0., 0.)]

# Reference timestamp for the observation series
reftime_obj = datetime(2020, 11, 26, 20, 0, 0)

# Flags to control overwriting existing data products
overwrite_ms   = False  # Overwrite measurement set?
overwrite_im   = False  # Overwrite image products?
overwrite_plot = True  # Overwrite existing plots?

# Deconvolution algorithm choice
#deconvolver = 'hogbom'
#niter = 0
#weighting = 'uniform'

deconvolver = 'multiscale'
niter = 10000

# Imaging parameters (in seconds)
integration_time = 1  # Time per integration
duration         = 1  # Total imaging duration

# %%
# %matplotlib inline
reload(fss)

import time

reftime = reftime_obj.strftime('%Y/%m/%d/%H:%M:%S')

figdir = os.path.join(project, figsubfolder)
if not os.path.exists(figdir):
    os.makedirs(figdir)
    
caltbdir = os.path.join(project, 'caltbs')
if not os.path.exists(caltbdir):
    os.makedirs(caltbdir)

for config_file in config_files:
    cfg_suffix = os.path.basename(config_file.rstrip(".cfg"))
    for freqstr, imsize, cell, scale in zip(freq_list, imsizes, cells, scales):
        solar_model = f'{model_dir}/solar_disk_model_20201126.{freqstr}.fits'
        for noise in noise_levels:
            for phaerr, amperr in cal_errors:
                phaerr_deg = np.rad2deg(phaerr * 2 * np.pi)
                gaintable = [f'{caltbdir}/caltb_FASR_corrupt_{phaerr_deg:.0f}deg.ph',
                             f'{caltbdir}/caltb_FASR_corrupt_{np.int_(amperr * 100)}pct.amp']
                msname = fss.make_msname(project, target, freqstr, reftime_obj, duration, integration_time, config_file, noise)
                imname = fss.make_imname(msname, deconvolver, phaerr, amperr)
                if niter == 0:
                    imname = imname.replace(deconvolver, 'dirty')
                msfile = f'{msname}.ms'
                if os.path.exists(msfile):
                    if overwrite_ms:
                        os.system('rm -rf ' + msfile)
                    else:
                        pass
                
                if not os.path.exists(msfile):
                    print('Start generating ms')
                    fss.generate_ms(config_file, solar_model, reftime, freqstr, integration_time=integration_time,
                                    duration=duration,
                                    msname=msfile, noise=noise, usehourangle=True)

                if os.path.exists(f'{imname}.image'):
                    if overwrite_im:
                        junk = ['.image', '.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                        for j in junk:
                            os.system(f'rm -rf {imname}{j}')

                if not os.path.exists(f'{imname}.image'):
                    tstart = time.time()
                    print('Start deconvolution')
                    if not os.path.exists(gaintable[0]):
                        gaintable = fss.generate_caltb(msfile, caltype=['ph', 'amp'], 
                                                       calerr=[phaerr, amperr], caltbdir=caltbdir)
                    clearcal(vis=msfile)
                    applycal(vis=msfile, gaintable=gaintable, applymode='calonly', calwt=False)
                    if deconvolver == 'hogbom':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)
                    elif deconvolver == 'multiscale':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, scales=scale, 
                               gain=0.2, cycleniter=200, minpsffraction=0.1, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)                        
                    junk = ['.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                    for j in junk:
                        os.system(f'rm -rf {imname}{j}')
                    tend = time.time()
                    print(f'deconvolution completed in {(tend - tstart)/60.:.2f} minutes')
                    

                figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.jpg')
                #figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.ar.jpg')
                if os.path.exists(figname):
                    if overwrite_plot:
                        os.system(f'rm -rf {figname}')

                if not os.path.exists(figname):
                    reload(fss)
                    ## cleaned image
                    image1 = imname + '.image'
                    ## model image
                    image2 = os.path.join(project+'/msfiles/Quiet_Sun/', os.path.basename(solar_model.replace('.fits', '.im')))
                    ## meta information of the images
                    image_meta = {'title': [f'Image ({deconvolver})', 'Model (convolved)'],
                                  'freq': freqstr.lstrip("0"),
                                  'array_config': config_file,
                                  'noise': f'{1e6 * float(noise.rstrip("MK")):.0f}K',
                                  'cal_error': f'{phaerr_deg:.0f}'+r'$^{\circ}$ Pha' + f' & {np.int_(amperr * 100)}% Amp',
                                  'duration': f'{duration}s',
                                  'weighting': weighting,
                                  }
                    print('Start plotting')
                    fig, axs = fss.plot_two_casa_images_with_convolution(image1, image2,
                                                                         crop_fraction=(0.0, 1.0),
                                                                         #crop_fraction=((0.17, 0.37), (0.25, 0.45)),
                                                                         figsize=(15, 4),
                                                                         image_meta=image_meta,
                                                                         cmap='inferno',
                                                                         vmax=50,
                                                                         compare_two=False,
                                                                         contour_levels=[0.025, 0.05, 0.1, 0.2, 0.4,
                                                                                         0.8],
                                                                         conv_tag=f'.{cfg_suffix}',
                                                                         overwrite_conv=False)

                    fig.savefig(figname, dpi=300)
# Out:
# Start plotting
# Peak of fasr_fasr-b_spiral_72_Quiet_Sun_1GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image: 1.315e+06 K
# rms of fasr_fasr-b_spiral_72_Quiet_Sun_1GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 6.351e+03 K
# SNR of the image: 207.1
# Plotting image with vmin=-6.351e+04 K, vmax=6.577e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2122: UserWarning: FixedFormatter should only be used together with FixedLocator
#   contour_levels = np.linspace(0.1, 0.9, 5) * np.nanmax(cropped1)
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2145: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Open two CASA images using casatools.image (IA), convolve the second image
# 'plot_two_casa_images_with_convolution' completed at 2026-01-29 10:22:47; runtime: 1.10 seconds
# Start plotting
# Peak of fasr_fasr-b_spiral_72_Quiet_Sun_2GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image: 5.296e+05 K
# rms of fasr_fasr-b_spiral_72_Quiet_Sun_2GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 3.967e+03 K
# SNR of the image: 133.5
# Plotting image with vmin=-3.967e+04 K, vmax=2.648e+05 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2122: UserWarning: FixedFormatter should only be used together with FixedLocator
#   contour_levels = np.linspace(0.1, 0.9, 5) * np.nanmax(cropped1)
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2145: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Open two CASA images using casatools.image (IA), convolve the second image
# 'plot_two_casa_images_with_convolution' completed at 2026-01-29 10:22:48; runtime: 0.90 seconds

# %% [markdown]
# ## Now do simulation using the PSI-MHD-derived model

# %%
# List of all available frequencies in GHz
#freq_list = ['0.20GHz', '0.40GHz', '1.00GHz', '1.59GHz', '2.00GHz']
#imsizes = [512, 512, 512, 512, 512]
#cells = ['8arcsec', '8arcsec', '8arcsec', '8arcsec', '8arcsec']
#scales = [[0, 4, 10, 50], [0, 4, 10, 40], [0, 4, 10, 40], [0, 4, 10, 40], [0, 4, 10, 40]]
freq_list = ['1.59GHz']
imsizes = [512]
cells = ['8arcsec']
scales = [[0, 4, 10, 40]]

# List of configurations
project = 'FASR-B'
config_files = ['fasr-b_spiral_72.cfg']

## Antenna temperature noise levels
noise_levels = ['0.005MK', '0.01MK'][:1]

## Define the fractional gain errors tuples: (phase and amplitude)
# 6 degrees (or 1.7% of phase error is equivalent to 10% of amplitude error )
#cal_errors = [(0., 0.), (0.017, 0.1)]
cal_errors = [(0., 0.)]

# Reference timestamp for the observation series
reftime_obj = datetime(2020, 11, 26, 20, 0, 0)

# Flags to control overwriting existing data products
overwrite_ms   = False  # Overwrite measurement set?
overwrite_im   = False  # Overwrite image products?
overwrite_plot = True  # Overwrite existing plots?

# Deconvolution algorithm choice
#deconvolver = 'hogbom'
#niter = 0
#weighting = 'uniform'

deconvolver = 'multiscale'
niter = 10000

# Imaging parameters (in seconds)
integration_time = 1  # Time per integration
duration         = 1  # Total imaging duration

# %%
# %matplotlib inline
reload(fss)

import time
import sunpy.visualization.colormaps as cm
import matplotlib
cmapxrt = matplotlib.colormaps['hinodexrt']

reftime = reftime_obj.strftime('%Y/%m/%d/%H:%M:%S')

figdir = os.path.join(project, figsubfolder)
if not os.path.exists(figdir):
    os.makedirs(figdir)
    
caltbdir = os.path.join(project, 'caltbs')
if not os.path.exists(caltbdir):
    os.makedirs(caltbdir)

for config_file in config_files:
    cfg_suffix = os.path.basename(config_file.rstrip(".cfg"))
    for freqstr, imsize, cell, scale in zip(freq_list, imsizes, cells, scales):
        solar_model = f'{model_dir}/psi_solar_disk_model_20201126.{freqstr}.fits'
        for noise in noise_levels:
            for phaerr, amperr in cal_errors:
                phaerr_deg = np.rad2deg(phaerr * 2 * np.pi)
                gaintable = [f'{caltbdir}/caltb_FASR_corrupt_{phaerr_deg:.0f}deg.ph',
                             f'{caltbdir}/caltb_FASR_corrupt_{np.int_(amperr * 100)}pct.amp']
                msname = fss.make_msname(project, target, freqstr, reftime_obj, duration, integration_time, config_file, noise)
                imname = fss.make_imname(msname, deconvolver, phaerr, amperr)
                if niter == 0:
                    imname = imname.replace(deconvolver, 'dirty')
                msfile = f'{msname}.ms'
                if os.path.exists(msfile):
                    if overwrite_ms:
                        os.system('rm -rf ' + msfile)
                    else:
                        pass
                
                if not os.path.exists(msfile):
                    print('Start generating ms')
                    fss.generate_ms(config_file, solar_model, reftime, freqstr, integration_time=integration_time,
                                    duration=duration,
                                    msname=msfile, noise=noise, usehourangle=True)

                if os.path.exists(f'{imname}.image'):
                    if overwrite_im:
                        junk = ['.image', '.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                        for j in junk:
                            os.system(f'rm -rf {imname}{j}')

                if not os.path.exists(f'{imname}.image'):
                    tstart = time.time()
                    print('Start deconvolution')
                    #if not os.path.exists(gaintable[0]):
                    gaintable = fss.generate_caltb(msfile, caltype=['ph', 'amp'], 
                                                       calerr=[phaerr, amperr], caltbdir=caltbdir)
                    clearcal(vis=msfile)
                    applycal(vis=msfile, gaintable=gaintable, applymode='calonly', calwt=False)
                    if deconvolver == 'hogbom':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)
                    elif deconvolver == 'multiscale':
                        tclean(vis=msfile, imagename=imname,
                               datacolumn='corrected',
                               field='', spw='', specmode='mfs', 
                               deconvolver=deconvolver, scales=scale, 
                               gain=0.2, cycleniter=200, minpsffraction=0.1, pblimit=0.01,
                               imsize=imsize, cell=cell,
                               weighting=weighting,
                               niter=niter,
                               interactive=False)                        
                    junk = ['.model', '.mask', '.pb', '.psf', '.residual', '.sumwt']
                    for j in junk:
                        os.system(f'rm -rf {imname}{j}')
                    tend = time.time()
                    print(f'deconvolution completed in {(tend - tstart)/60.:.2f} minutes')
                    

                figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.jpg')
                #figname = os.path.join(figdir, f'fig-{os.path.basename(imname)}.ar.jpg')
                if os.path.exists(figname):
                    if overwrite_plot:
                        os.system(f'rm -rf {figname}')

                if not os.path.exists(figname):
                    reload(fss)
                    ## cleaned image
                    image1 = imname + '.image'
                    ## model image
                    image2 = os.path.join(project+'/msfiles/Quiet_Sun/', os.path.basename(solar_model.replace('.fits', '.im')))
                    ## meta information of the images
                    image_meta = {'title': [f'Image ({deconvolver})', 'Model (convolved)'],
                                  'freq': freqstr,
                                  'array_config': config_file,
                                  'noise': f'{1e6 * float(noise.rstrip("MK")):.0f}K',
                                  'cal_error': f'{phaerr_deg:.0f}'+r'$^{\circ}$ Pha' + f' & {np.int_(amperr * 100)}% Amp',
                                  'duration': f'{duration}s',
                                  'weighting': weighting,
                                  }
                    print('Start plotting')
                    fig, axs = fss.plot_two_casa_images_with_convolution(image1, image2,
                                                                         crop_fraction=(0.0, 1.0), rms_mask_radius=1.6,
                                                                         #crop_fraction=((0.17, 0.37), (0.25, 0.45)),
                                                                         figsize=(15, 4),
                                                                         image_meta=image_meta,
                                                                         cmap=cmapxrt,
                                                                         vmax=100,
                                                                         compare_two=False,
                                                                         contour_levels=[0.025, 0.05, 0.1, 0.2, 0.4,
                                                                                         0.8],
                                                                         conv_tag=f'.{cfg_suffix}',
                                                                         overwrite_conv=False)

                    fig.savefig(figname, dpi=300)
# Out:
# Start deconvolution
# Generated phase calibration table: FASR-B/caltbs/caltb_FASR_corrupt_0deg.ph
# Generated amplitude calibration table: caltb_FASR_corrupt_0pct.amp
# 2026-01-31 20:59:21	WARN	clearcal::calibrater::setvi(bool,bool)	Forcing use of OLD VisibilityIterator.
# 2026-01-31 20:59:21	WARN	SynthesisParamsImage::buildCoordinateSystem (file src/code/synthesis/ImagerObjects/SynthesisUtilMethods.cc, line 2501)	Did not get the position of FASR from data repository
# 2026-01-31 20:59:21	WARN	SynthesisParamsImage::buildCoordinateSystem (file src/code/synthesis/ImagerObjects/SynthesisUtilMethods.cc, line 2501)	Please contact CASA to add it to the repository.
# 2026-01-31 20:59:21	WARN	SynthesisParamsImage::buildCoordinateSystem (file src/code/synthesis/ImagerObjects/SynthesisUtilMethods.cc, line 2501)	Using first antenna position as refence
# 2026-01-31 20:59:28	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 20:59:35	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 20:59:39	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 20:59:58	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:14	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:24	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:27	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:30	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:33	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:34	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:37	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:56	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:56	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:00:56	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:00	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:07	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:10	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:19	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:23	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:26	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:30	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:33	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:33	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:39	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:50	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:50	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:51	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# 2026-01-31 21:01:54	WARN	SDAlgorithmMSClean::takeOneStep (file src/code/synthesis/ImagerObjects/SDAlgorithmMSClean.cc, line 185)	MSClean minor cycle stopped at large scale negative or diverging
# deconvolution completed in 2.69 minutes
# Start plotting
# Peak of fasr_fasr-b_spiral_72_Quiet_Sun_1.59GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image: 1.584e+06 K
# rms of fasr_fasr-b_spiral_72_Quiet_Sun_1.59GHz_20201126T20UT_dur1s_int1s_noise0.005MK_phaerr0deg_amperr0pct_multiscale.image (excluding solar disk): 5.624e+03 K
# SNR of the image: 281.6
# Plotting image with vmin=-5.624e+04 K, vmax=1.584e+06 K
# Plotting convolved image with vmin=-5.624e+04 K, vmax=1.584e+06 K
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2327: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2 = axs[-1]
# /Users/binchen/Dropbox/Projects/FASR/fasr-array-config-simul/fasr_solar_simul.py:2356: UserWarning: FixedFormatter should only be used together with FixedLocator
# 'plot_two_casa_images_with_convolution' completed at 2026-01-31 16:02:02; runtime: 1.08 seconds
